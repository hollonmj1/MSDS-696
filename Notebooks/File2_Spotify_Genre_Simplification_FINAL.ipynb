# %% [markdown]
# ## MSDS 696        Notebook2  Simplify Spotify Artist Genres
#
#
# ### Project Title:
# Create and Build A Data Engineering Pipeline to Collect, Process, and Store Spotify Data. This is intended to be a fun project to look at who the most popular artists are, what their most popular tracks are , and look at some characteristics of the songs.
#
# ### Notebook Purpose:
#
# The purpose of this file is to simplify the genres associated with each Spotify artist with the end result being one overarching genre in a new feature named simplified_genre.
#
# ###  Mary J Hollon
# ### Due 8-22-2024

# %%
# import libraries

import os
import pandas as pd
import numpy as np

# %% [markdown]
# The reasoning here is to develop working code for one file and then apply the code to all the files.

# %%
# Load the CSV file
df = pd.read_csv('artists_2015.csv')

df.head(20)
# Out:
#                         id               name  popularity  \
# 0   06HL4z0CvFAxyc27GXpf02       Taylor Swift         100
# 1   3TVXtAsR1Inumwj472S9r4              Drake          95
# 2   4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen          91
# 3   2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar          92
# 4   5K4W6rqBFWDnAN6FQUkS6x         Kanye West          92
# 5   7dGJo4pcD2V6oG8kP0tJRR             Eminem          93
# 6   1RyvyyTE3xzB2ZywiAwp0i             Future          91
# 7   0Y5tJX1MQlPlqiwlOH1tJY       Travis Scott          93
# 8   246dkjvS1zLTtiykXe5h60        Post Malone          91
# 9   1Xyo4u8uXC1ZmMpatF05PJ         The Weeknd          94
# 10  4q3ewBCX7sLwd24euuV69X          Bad Bunny          94
# 11  0iEtIxbK0KxaSlF7G42ZOp       Metro Boomin          89
# 12  1VPmR4DJC1PlOtd0IADAO0        $uicideboy$          86
# 13  7tYKF4w9nC0nq9CsPZTHyP                SZA          89
# 14  1URnnhqYAYcrqrcwql10ft          21 Savage          88
# 15  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter          90
# 16  00FQb4jTyendYWaN8pK0wa       Lana Del Rey          91
# 17  25uiPmTg16RbhZWAqwLBy5         Charli xcx          88
# 18  5pKCCKE2ajJHZ9KAiaK11H            Rihanna          90
# 19  66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande          91
#
#                                                genres  year
# 0                                             ['pop']  2015
# 1   ['canadian hip hop', 'canadian pop', 'hip hop'...  2015
# 2                            ['contemporary country']  2015
# 3   ['conscious hip hop', 'hip hop', 'rap', 'west ...  2015
# 4                   ['chicago rap', 'hip hop', 'rap']  2015
# 5               ['detroit hip hop', 'hip hop', 'rap']  2015
# 6   ['atl hip hop', 'hip hop', 'rap', 'southern hi...  2015
# 7                               ['rap', 'slap house']  2015
# 8            ['dfw rap', 'melodic rap', 'pop', 'rap']  2015
# 9   ['canadian contemporary r&b', 'canadian pop', ...  2015
# 10      ['reggaeton', 'trap latino', 'urbano latino']  2015
# 11                                            ['rap']  2015
# 12  ['cloud rap', 'dark trap', 'new orleans rap', ...  2015
# 13                              ['pop', 'r&b', 'rap']  2015
# 14                  ['atl hip hop', 'hip hop', 'rap']  2015
# 15                                            ['pop']  2015
# 16                                 ['art pop', 'pop']  2015
# 17  ['art pop', 'candy pop', 'metropopolis', 'pop'...  2015
# 18     ['barbadian pop', 'pop', 'urban contemporary']  2015
# 19                                            ['pop']  2015

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          400 non-null    object
#  1   name        400 non-null    object
#  2   popularity  400 non-null    int64
#  3   genres      400 non-null    object
#  4   year        400 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 15.8+ KB

# %%
# Let's look at just the genres
all_genres = df['genres'].str.split(',').explode().unique()
all_genres
# Out:
# array(["['pop']", "['canadian hip hop'", " 'canadian pop'", " 'hip hop'",
#        " 'pop rap'", " 'rap']", "['contemporary country']",
#        "['conscious hip hop'", " 'rap'", " 'west coast rap']",
#        "['chicago rap'", "['detroit hip hop'", "['atl hip hop'",
#        " 'southern hip hop'", " 'trap']", "['rap'", " 'slap house']",
#        "['dfw rap'", " 'melodic rap'", " 'pop'",
#        "['canadian contemporary r&b'", " 'pop']", "['reggaeton'",
#        " 'trap latino'", " 'urbano latino']", "['rap']", "['cloud rap'",
#        " 'dark trap'", " 'new orleans rap'", " 'underground hip hop']",
#        "['pop'", " 'r&b'", "['art pop'", " 'candy pop'",
#        " 'metropopolis'", " 'uk pop']", "['barbadian pop'",
#        " 'urban contemporary']", "['lgbtq+ hip hop'", " 'neo soul']",
#        "['hip hop'", "['emo rap'", " 'miami hip hop'",
#        " 'north carolina hip hop'", " 'reggaeton colombiano'", " 'plugg'",
#        " 'pluggnb'", " 'rage rap'", " 'philly rap'",
#        "['irish singer-songwriter'", " 'modern rock'", " 'pov: indie']",
#        "['r&b'", " 'trap'", " 'trap soul']", "['dance pop'",
#        "['contemporary country'", " 'outlaw country']", "['hip pop'",
#        " 'queens hip hop'", "['colombian pop'", " 'pop reggaeton'",
#        " 'reggaeton'", "['canadian pop'", " 'r&b']", '[]',
#        "['permanent wave'", "['puerto rican pop'",
#        "['east coast hip hop'", "['country rap'", " 'nashville hip hop'",
#        " 'tennessee hip hop']", "['k-pop']", "['colombian pop']",
#        " 'pop r&b']", "['big room'", " 'dance pop'", " 'edm'",
#        " 'pop dance']", " 'atl trap'", " 'gangster rap'",
#        "['modern rock'", " 'rock']", " 'pittsburgh rap'",
#        " 'electro house'", " 'house'", " 'progressive house'",
#        " 'uk dance']", "['kentucky indie'", " 'kentucky roots'",
#        "['alternative metal'", " 'nu metal'", " 'post-grunge'",
#        " 'rap metal'", "['british invasion'", " 'classic rock'",
#        " 'merseybeat'", " 'psychedelic rock'", " 'emo rap'",
#        " 'lgbtq+ hip hop']", "['florida drill'", " 'florida rap'",
#        " 'trap latino']", "['chicago drill'", " 'chicago rap'",
#        " 'drill'", "['kentucky hip hop'", "['afrofuturism']",
#        "['bedroom pop'", " 'indie pop'", "['pov: indie']",
#        "['brooklyn indie'", " 'singer-songwriter pop'", "['album rock'",
#        " 'rock'", " 'soft rock'", " 'yacht rock']", "['environmental'",
#        " 'sleep'", " 'sound'", " 'water']", "['brostep'",
#        " 'progressive electro house']", "['modern alternative rock'",
#        " 'reggaeton flow'", " 'trap boricua'", " 'pov: indie'",
#        "['piano rock'", " 'canadian trap'", "['ambient pop'",
#        " 'dream pop'", " 'el paso indie'", " 'shoegaze']",
#        "['latin hip hop'", " 'contemporary r&b'",
#        " 'south carolina hip hop'", "['g funk'", "['r&b']",
#        "['hard rock'", " 'metal'", " 'old school thrash'",
#        " 'thrash metal']", "['plugg']", "['british soul'", " 'pop soul'",
#        "['alt z'", " 'electropop'", "['classic rock'", " 'glam rock'",
#        " 'permanent wave'", " 'punk'", "['edmonton indie'",
#        " 'lo-fi indie'", " 'slacker rock']", "['classic texas country'",
#        " 'country dawn']", "['melodic rap'", "['memphis hip hop'",
#        " 'tennessee hip hop'", "['ohio hip hop'", " 'pop rap']",
#        " 'country'", " 'country road'", " 'modern country rock']",
#        " 'latin pop'", "['k-pop'", " 'k-pop boy group'", " 'soul']",
#        "['folk-pop'", " 'neo mellow'", " 'stomp and holler']",
#        "['canadian contemporary r&b']", " 'modern country pop']",
#        "['glam rock'", " 'mellow gold'", " 'piano rock'",
#        " 'contemporary country'", " 'ohio hip hop'",
#        "['australian psych'", " 'neo-psychedelic'", "['emo'",
#        " 'pop punk'", "['alternative rock'", " 'art rock'",
#        " 'melancholia'", " 'oxford indie'", "['boy band'",
#        " 'post-teen pop'", " 'talent show']", "['electropop'",
#        " 'etherpop'", " 'indie poptimism'", "['gauze pop'",
#        " 'indietronica'", " 'shiver pop']", "['reggae'",
#        " 'roots reggae']", " 'brostep'", " 'dutch edm'", " 'pop dance'",
#        " 'progressive electro house'", " 'slap house'", " 'trance']",
#        "['latin pop'", "['corrido'", " 'sierreno']", " 'canadian rock'",
#        " 'post-grunge']", " 'socal pop punk']", "['bachata'",
#        " 'latin hip hop'", " 'singer-songwriter'", " 'soft rock']",
#        "['dance pop']", " 'country road']", " 'british invasion'",
#        "['deep underground hip hop'", " 'kentucky hip hop'",
#        " 'viral pop']", "['black americana'", "['filmi'",
#        " 'modern bollywood']", "['chicago bop'", " 'chicago drill'",
#        " 'dirty south rap'", "['neo mellow'", " 'singer-songwriter']",
#        " 'puerto rican pop'", " 'moombahton'", " 'punk blues'",
#        "['rap rock'", " 'reggae fusion'", " 'ska mexicano'",
#        " 'ska punk']", "['philly indie'", "['melodic metalcore'",
#        " 'metalcore'", " 'uk metalcore']", "['indie pop'", " 'la indie'",
#        " 'old school atlanta hip hop'", "['ccm'", " 'christian music'",
#        " 'worship']", "['escape room'", " 'indie soul'",
#        " 'alternative rock'", "['edm'", " 'tropical house']",
#        " 'post-teen pop']", "['hawaiian hip hop'", "['neo mellow']",
#        " 'dance rock'", " 'country pop'", " 'hardcore hip hop'",
#        "['dirty south rap'", "['electro'", " 'filter house'",
#        " 'instrumental hip hop'", " 'screamo']", "['grupera'",
#        " 'musica mexicana']", "['classic oklahoma country'",
#        "['baton rouge rap'", " 'bachata dominicana'", " 'tropical'",
#        "['banda'", " 'musica mexicana'", " 'norteno'", " 'sad sierreno']",
#        "['europop'", " 'swedish pop']", " 'canadian metal'", " 'nz pop'",
#        " 'southern hip hop']", " 'norteno']", " 'modern power pop'",
#        "['heartland rock'", "['australian dance'",
#        " 'australian electropop'", " 'neo-synthpop']", " 'hard rock'",
#        "['neo soul'", "['dark trap'", " 'funk metal'",
#        "['adult standards'", " 'easy listening'", " 'lounge']",
#        " 'indian instrumental'", " 'folk'", " 'folk rock'", "['cali rap'",
#        "['dembow'", " 'rap dominicano'", "['indie pop rap'",
#        " 'oakland hip hop'", "['noise pop'", "['indietronica'",
#        " 'groove metal'", " 'nu metal']", "['alternative r&b']",
#        " 'skate punk'", "['arkansas country'", " 'outlaw country'",
#        "['baroque pop'", " 'uk alternative pop']", " 'dancehall'",
#        "['country']", " 'pop rock']", " 'st louis rap'",
#        "['rock-and-roll'", " 'rockabilly']", "['broadway'",
#        " 'show tunes']", "['trop rock']", " 'southern rock']",
#        "['gangster rap'", " 'ranchera']", " 'rap metal']", " 'corrido'",
#        " 'musica bajacaliforniana'", "['australian pop'", " 'grunge'",
#        " 'spacegrunge']", " 'latin viral pop'", " 'rap latina'",
#        "['pop rap'", " 'seattle hip hop']", "['alternative metal']",
#        " 'k-pop boy group']", "['glam metal'", " 'indie rock'",
#        "['art rock'", " 'electronic trap'", "['irish rock'",
#        " 'pop rock'", "['mariachi'", "['electro house']",
#        "['reggae fusion'", " 'reggae rock']", "['electro latino'",
#        " 'grupera'", "['trap boricua'", " 'trap triste'",
#        " 'sunshine pop']", " 'country dawn'", " 'conscious hip hop'",
#        " 'dark trap']", " 'sad sierreno'", " 'memphis hip hop'",
#        "['pittsburgh rap']", "['classic country pop'",
#        " 'classic texas country'", " 'country rock'",
#        " 'nashville sound'", " 'modern rock']", " 'k-pop girl group'",
#        " 'talent show'", "['motown'", "['pop reggaeton'",
#        "['canadian latin'", "['indie folk'", " 'complextro'",
#        " 'electro'", "['disco'", "['modern country pop']", "['crunk'",
#        "['gruperas inmortales'", " 'nu-cumbia'", " 'ranchera'",
#        " 'tropical']", " 'blues rock'", " 'garage rock'",
#        " 'modern blues rock'", "['newcastle nsw indie'", " 'crunk'",
#        " 'sophisti-pop']", " 'modern blues'", " 'neo soul'",
#        "['alternative r&b'", " 'funk'", " 'jazz funk'", " 'motown'",
#        "['r&b en espanol'", " 'spanish hip hop'", " 'urbano espanol'",
#        "['indie poptimism'", " 'escape room'", "['classic soul'",
#        " 'northern soul'", " 'quiet storm'", " 'rap rock'", "['baroque'",
#        " 'classical'", " 'early music'", " 'german baroque']",
#        "['canadian americana'", " 'canadian contemporary country'",
#        " 'saskatchewan indie']", "['afrobeats'", " 'afropop'",
#        " 'azonto'", " 'nigerian hip hop'", " 'nigerian pop']",
#        "['belgian edm'", "['rock drums'", " 'heartland rock'",
#        " 'country']", "['pop soul']", "['complextro'", " 'german techno'",
#        "['new wave'", " 'uk post-punk']", "['german soundtrack'",
#        " 'orchestral soundtrack'", " 'soundtrack']", "['panamanian pop'",
#        " 'modern alternative rock'", " 'g funk'",
#        "['alternative hip hop'", " 'drumless hip hop'", " 'show tunes'",
#        " 'vocal jazz']", "['pixel'", " 'video game music']",
#        " 'experimental hip hop'", " 'industrial hip hop'",
#        " 'mexican pop']", "['indie soul'", " 'world']",
#        "['compositional ambient'", " 'neo-classical']", "['funk pop'",
#        " 'funk rj'", " 'pagode baiano'", " 'pop nacional']",
#        " 'swedish electropop'", " 'swedish pop'", " 'swedish synthpop']",
#        "['pluggnb'", " 'redneck']", " 'melodic dubstep'",
#        " 'new jersey rap'", " 'baltimore indie'", " 'dreamo'",
#        " 'modern dream pop'", " 'kansas city hip hop'",
#        "['electro house'", " 'pop nacional'", " 'modern country pop'",
#        " 'texas country']", " 'metal']", "['cosmic american'",
#        " 'jam band'", " 'psychedelic rock']", " 'uk contemporary r&b']",
#        "['latin arena pop'", " 'latin rock'", " 'mexican pop'",
#        " 'mexican rock'", " 'rock en espanol']"], dtype=object)

# %% [markdown]
# As can be seen, the genres are messy and need simplification !

# %%
# Count the number of unique genres
unique_genres_count = len(all_genres)

# Display the count of unique genres
unique_genres_count
# Out:
# 268

# %% [markdown]
# There are 268 different types of genres ! This is not sustainable to work with and needs to be simplified !
# Since I am not an expert, here are some useful websites to help explain music genres: https://gearaficionado.com/blog/music-genres-list/,  https://en.wikipedia.org/wiki/List_of_music_genres_and_styles

# %%
# List of detailed genres and their simplified classifications limited to 100 genres
# This is my attempt to simplify, this is a trial and error process
genres = [
    ('hip hop', 'Hip Hop'),
    ('pop', 'Pop'),
    ('rock', 'Rock'),
    ('country', 'Country'),
    ('blues', 'Blues'),
    ('electronic', 'Electronic'),
    ('reggae', 'Reggae'),
    ('metal', 'Metal'),
    ('funk','Funk'),
    ('r&b', 'R&B'),
    ('soul', 'Soul'),
    ('punk', 'Punk'),
    ('alternative', 'Alternative'),
    ('indie', 'Indie'),
    ('house', 'House'),
    ('trance', 'Trance'),
    ('rap', 'Rap'),
    ('new age', 'New Age'),
    ('opera', 'Opera'),
    ('gospel', 'Gospel'),
    ('k-pop', 'K-Pop'),
    ('j-pop', 'J-Pop'),
    ('world', 'World'),
    ('grime', 'Grime'),
    ('reggaeton', 'Reggaeton'),
    ('synth', 'Synth'),
    ('blues-rock', 'Blues-Rock'),
    ('trip hop', 'Trip Hop'),
    ('swing', 'Swing'),
    ('bossa nova', 'Bossa Nova'),
    ('bluegrass', 'Bluegrass'),
    ('ska', 'Ska'),
    ('drum and bass', 'Drum and Bass'),
    ('garage', 'Garage'),
    ('grunge', 'Grunge'),
    ('industrial', 'Industrial'),
    ('metalcore', 'Metalcore'),
    ('celtic', 'Celtic'),
    ('fusion', 'Fusion'),
    ('psychedelic', 'Psychedelic'),
    ('glam', 'Glam'),
    ('lo-fi', 'Lo-Fi'),
    ('shoegaze', 'Shoegaze'),
    ('chill', 'Chill'),
    ('downtempo', 'Downtempo'),
    ('exotica', 'Exotica'),
    ('surf', 'Surf'),
    ('space', 'Space'),
    ('prog', 'Prog'),
    ('hardcore', 'Hardcore'),
    ('post', 'Post'),
    ('dark', 'Dark'),
    ('minimal', 'Minimal'),
    ('experimental', 'Experimental'),
    ('symphonic', 'Symphonic'),
    ('emo rap', 'Emo Rap'),
    ('post rock', 'Post Rock'),
    ('avant-garde', 'Avant-Garde'),
    ('nu-metal', 'Nu-Metal'),
    ('kawaii', 'Kawaii'),
    ('anime', 'Anime'),
    ('drone', 'Drone'),
    ('noise', 'Noise'),
    ('breakbeat', 'Breakbeat'),
    ('britpop', 'Britpop'),
    ('yacht rock', 'Yacht Rock'),
    ('vaporwave', 'Vaporwave'),
    ('neo-soul', 'Neo-Soul'),
    ('synthwave', 'Synthwave'),
    ('trap', 'Trap'),
    ('future bass', 'Future Bass'),
    ('moombahton', 'Moombahton'),
    ('tropical house', 'Tropical House'),
    ('kawaii future bass', 'Kawaii Future Bass'),
    ('industrial rock', 'Industrial Rock'),
    ('darkwave', 'Darkwave'),
    ('dark ambient', 'Dark Ambient'),
    ('steampunk', 'Steampunk'),
    ('gothic', 'Gothic'),
    ('black metal', 'Black Metal'),
    ('doom metal', 'Doom Metal'),
    ('death metal', 'Death Metal')
]

# Create the genre dictionary
genre_dict = {key: value for key, value in genres}

# %%
print(genre_dict)
# Out:
# {'hip hop': 'Hip Hop', 'pop': 'Pop', 'rock': 'Rock', 'country': 'Country', 'blues': 'Blues', 'electronic': 'Electronic', 'reggae': 'Reggae', 'metal': 'Metal', 'funk': 'Funk', 'r&b': 'R&B', 'soul': 'Soul', 'punk': 'Punk', 'alternative': 'Alternative', 'indie': 'Indie', 'house': 'House', 'trance': 'Trance', 'rap': 'Rap', 'new age': 'New Age', 'opera': 'Opera', 'gospel': 'Gospel', 'k-pop': 'K-Pop', 'j-pop': 'J-Pop', 'world': 'World', 'grime': 'Grime', 'reggaeton': 'Reggaeton', 'synth': 'Synth', 'blues-rock': 'Blues-Rock', 'trip hop': 'Trip Hop', 'swing': 'Swing', 'bossa nova': 'Bossa Nova', 'bluegrass': 'Bluegrass', 'ska': 'Ska', 'drum and bass': 'Drum and Bass', 'garage': 'Garage', 'grunge': 'Grunge', 'industrial': 'Industrial', 'metalcore': 'Metalcore', 'celtic': 'Celtic', 'fusion': 'Fusion', 'psychedelic': 'Psychedelic', 'glam': 'Glam', 'lo-fi': 'Lo-Fi', 'shoegaze': 'Shoegaze', 'chill': 'Chill', 'downtempo': 'Downtempo', 'exotica': 'Exotica', 'surf': 'Surf', 'space': 'Space', 'prog': 'Prog', 'hardcore': 'Hardcore', 'post': 'Post', 'dark': 'Dark', 'minimal': 'Minimal', 'experimental': 'Experimental', 'symphonic': 'Symphonic', 'emo rap': 'Emo Rap', 'post rock': 'Post Rock', 'avant-garde': 'Avant-Garde', 'nu-metal': 'Nu-Metal', 'kawaii': 'Kawaii', 'anime': 'Anime', 'drone': 'Drone', 'noise': 'Noise', 'breakbeat': 'Breakbeat', 'britpop': 'Britpop', 'yacht rock': 'Yacht Rock', 'vaporwave': 'Vaporwave', 'neo-soul': 'Neo-Soul', 'synthwave': 'Synthwave', 'trap': 'Trap', 'future bass': 'Future Bass', 'moombahton': 'Moombahton', 'tropical house': 'Tropical House', 'kawaii future bass': 'Kawaii Future Bass', 'industrial rock': 'Industrial Rock', 'darkwave': 'Darkwave', 'dark ambient': 'Dark Ambient', 'steampunk': 'Steampunk', 'gothic': 'Gothic', 'black metal': 'Black Metal', 'doom metal': 'Doom Metal', 'death metal': 'Death Metal'}

# %%
# Load the artists dataset
artists_df = pd.read_csv('artists_2015.csv')


# Function to classify genre
def classify_genre(genres):
    if isinstance(genres, str):  # Check if the genre is a string
        for genre in genres.split(', '):  # Split the genre string into individual genres
            for key, value in genre_dict.items():
                if key in genre.lower():  # Check if the key is in the genre
                    return value  # Return the simplified genre
    return 'Other'  # Default classification for unmatched genres

# Apply the classification to the genres column
artists_df['simplified_genre'] = artists_df['genres'].apply(classify_genre)

# Display the first few rows to see the results
artists_df.head(20)
# Out:
#                         id               name  popularity  \
# 0   06HL4z0CvFAxyc27GXpf02       Taylor Swift         100
# 1   3TVXtAsR1Inumwj472S9r4              Drake          95
# 2   4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen          91
# 3   2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar          92
# 4   5K4W6rqBFWDnAN6FQUkS6x         Kanye West          92
# 5   7dGJo4pcD2V6oG8kP0tJRR             Eminem          93
# 6   1RyvyyTE3xzB2ZywiAwp0i             Future          91
# 7   0Y5tJX1MQlPlqiwlOH1tJY       Travis Scott          93
# 8   246dkjvS1zLTtiykXe5h60        Post Malone          91
# 9   1Xyo4u8uXC1ZmMpatF05PJ         The Weeknd          94
# 10  4q3ewBCX7sLwd24euuV69X          Bad Bunny          94
# 11  0iEtIxbK0KxaSlF7G42ZOp       Metro Boomin          89
# 12  1VPmR4DJC1PlOtd0IADAO0        $uicideboy$          86
# 13  7tYKF4w9nC0nq9CsPZTHyP                SZA          89
# 14  1URnnhqYAYcrqrcwql10ft          21 Savage          88
# 15  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter          90
# 16  00FQb4jTyendYWaN8pK0wa       Lana Del Rey          91
# 17  25uiPmTg16RbhZWAqwLBy5         Charli xcx          88
# 18  5pKCCKE2ajJHZ9KAiaK11H            Rihanna          90
# 19  66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande          91
#
#                                                genres  year simplified_genre
# 0                                             ['pop']  2015              Pop
# 1   ['canadian hip hop', 'canadian pop', 'hip hop'...  2015          Hip Hop
# 2                            ['contemporary country']  2015          Country
# 3   ['conscious hip hop', 'hip hop', 'rap', 'west ...  2015          Hip Hop
# 4                   ['chicago rap', 'hip hop', 'rap']  2015              Rap
# 5               ['detroit hip hop', 'hip hop', 'rap']  2015          Hip Hop
# 6   ['atl hip hop', 'hip hop', 'rap', 'southern hi...  2015          Hip Hop
# 7                               ['rap', 'slap house']  2015              Rap
# 8            ['dfw rap', 'melodic rap', 'pop', 'rap']  2015              Rap
# 9   ['canadian contemporary r&b', 'canadian pop', ...  2015              R&B
# 10      ['reggaeton', 'trap latino', 'urbano latino']  2015           Reggae
# 11                                            ['rap']  2015              Rap
# 12  ['cloud rap', 'dark trap', 'new orleans rap', ...  2015              Rap
# 13                              ['pop', 'r&b', 'rap']  2015              Pop
# 14                  ['atl hip hop', 'hip hop', 'rap']  2015          Hip Hop
# 15                                            ['pop']  2015              Pop
# 16                                 ['art pop', 'pop']  2015              Pop
# 17  ['art pop', 'candy pop', 'metropopolis', 'pop'...  2015              Pop
# 18     ['barbadian pop', 'pop', 'urban contemporary']  2015              Pop
# 19                                            ['pop']  2015              Pop

# %%
# Counting the number of unique simplified genres
unique_simplified_genres_count = artists_df['simplified_genre'].nunique()

unique_simplified_genres_count
# Out:
# 13

# %% [markdown]
# #### There are now 13 unique genres including other. This is much more manageable !

# %%
genre_counts = artists_df['simplified_genre'].value_counts()
genre_counts
# Out:
# Pop        116
# Hip Hop     69
# Rock        47
# Country     35
# Other       29
# Rap         26
# Metal       21
# R&B         13
# Reggae      12
# Indie       12
# Soul        10
# Funk         5
# House        5
# Name: simplified_genre, dtype: int64

# %% [markdown]
# Now we need to simplify the genres of all years of Spotify Data. We just did 2015 by itself because I want to make sure I have working code that accomplishes the task at hand. Next we will apply a loop to simplify the genres. BUT - first we will save the updated artists file with the simplified genre.

# %%
# Save the updated dataframe with simplified genres to a new CSV file
output_file = 'artists_2015_genre_new.csv'
artists_df.to_csv(output_file, index=False)

# %%
df = pd.read_csv('artists_2015_genre_new.csv')
df.head()
# Out:
#                        id            name  popularity  \
# 0  06HL4z0CvFAxyc27GXpf02    Taylor Swift         100
# 1  3TVXtAsR1Inumwj472S9r4           Drake          95
# 2  4oUHIQIBe0LHzYfvXNW4QM   Morgan Wallen          91
# 3  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar          92
# 4  5K4W6rqBFWDnAN6FQUkS6x      Kanye West          92
#
#                                               genres  year simplified_genre
# 0                                            ['pop']  2015              Pop
# 1  ['canadian hip hop', 'canadian pop', 'hip hop'...  2015          Hip Hop
# 2                           ['contemporary country']  2015          Country
# 3  ['conscious hip hop', 'hip hop', 'rap', 'west ...  2015          Hip Hop
# 4                  ['chicago rap', 'hip hop', 'rap']  2015              Rap

# %% [markdown]
# OK - Just checking ! It looks Good !

# %%
import os

# Printing the current directory path
current_directory = os.getcwd()
current_directory
# Out:
# 'C:\\Users\\mjhol\\OneDrive\\MSDS 696 Practium 2\\Notebooks'

# %%
# Directory where the files are stored
data_directory = current_directory

# Define the years for which to process files, remember 2014 was handled separately as a test
years = range(2016, 2025)


# Function to classify genre
def classify_genre(genres):
    if isinstance(genres, str):  # Check if the genre is a string
        for genre in genres.split(', '):  # Split the genre string into individual genres
            for key, value in genre_dict.items():
                if key in genre.lower():  # Check if the key is in the genre
                    return value  # Return the simplified genre
    return 'Other'  # Default classification for unmatched genres


# Loop through each year and process the corresponding file
for year in years:
    # Construct the file path
    input_file = f'artists_{year}.csv'
    input_file_path = os.path.join(data_directory, input_file)
    
    # Check if the file exists
    if os.path.exists(input_file_path):
        # Read the data
        df = pd.read_csv(input_file_path)
        
        # Apply the classification to the genres column
        df['simplified_genre'] = df['genres'].apply(classify_genre)
        
        # Save the updated dataframe to a new CSV file
        output_file = f'artists_{year}_genre_new.csv'
        output_file_path = os.path.join(data_directory, output_file)
        df.to_csv(output_file_path, index=False)

output_file_path
# Out:
# 'C:\\Users\\mjhol\\OneDrive\\MSDS 696 Practium 2\\Notebooks\\artists_2024_genre_new.csv'

# %% [markdown]
# OK - let's check one !

# %%
df = pd.read_csv('artists_2024_genre_new.csv')
df.head()
# Out:
#                        id            name  popularity  \
# 0  06HL4z0CvFAxyc27GXpf02    Taylor Swift         100
# 1  3TVXtAsR1Inumwj472S9r4           Drake          95
# 2  40ZNYROS4zLfyyBSs2PGe2      Zach Bryan          91
# 3  4oUHIQIBe0LHzYfvXNW4QM   Morgan Wallen          91
# 4  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar          92
#
#                                               genres  year simplified_genre
# 0                                            ['pop']  2024              Pop
# 1  ['canadian hip hop', 'canadian pop', 'hip hop'...  2024          Hip Hop
# 2                       ['classic oklahoma country']  2024          Country
# 3                           ['contemporary country']  2024          Country
# 4  ['conscious hip hop', 'hip hop', 'rap', 'west ...  2024          Hip Hop

# %%
df = pd.read_csv('artists_2020_genre_new.csv')
df.head()
# Out:
#                        id           name  popularity  \
# 0  6JMGrupbzJZ3yuQhTGyeHr      Year 200X          15
# 1  06HL4z0CvFAxyc27GXpf02   Taylor Swift         100
# 2  3TVXtAsR1Inumwj472S9r4          Drake          95
# 3  40ZNYROS4zLfyyBSs2PGe2     Zach Bryan          91
# 4  4oUHIQIBe0LHzYfvXNW4QM  Morgan Wallen          91
#
#                                               genres  year simplified_genre
# 0                                      ['scorecore']  2020            Other
# 1                                            ['pop']  2020              Pop
# 2  ['canadian hip hop', 'canadian pop', 'hip hop'...  2020          Hip Hop
# 3                       ['classic oklahoma country']  2020          Country
# 4                           ['contemporary country']  2020          Country

# %% [markdown]
# Looks Good !

# %% [markdown]
# ### Summary:
# The purpose of this notebook was to simplify the genres found in artists data files pulled from Spotify.
# The data files simplified consisted of the last 10 years of popular artists and their genres:
#
#  - artists_2015.csv
#  - artists_2016.csv
#  - artists_2017.csv
#  - artists_2018.csv
#  - artists_2019.csv
#  - artists_2020.csv
#  - artists_2021.csv
#  - artists_2022.csv
#  - artists_2023.csv
#  - artists_2024.csv
#
#  The processed files with the simplified genres were renamed to:
#
#  - artists_2015_genre_new.csv
#  - artists_2016_genre_new.csv
#  - artists_2017_genre_new.csv
#  - artists_2018_genre_new.csv
#  - artists_2019_genre_new.csv
#  - artists_2020_genre_new.csv
#  - artists_2021_genre_new.csv
#  - artists_2022_genre_new.csv
#  - artists_2023_genre_new.csv
#  - artists_2024_genre_new.csv

# %% [markdown]
# ### END OF NOTEBOOK
