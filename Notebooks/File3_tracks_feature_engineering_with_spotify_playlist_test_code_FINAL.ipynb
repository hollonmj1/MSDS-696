# %% [markdown]
# ## MSDS 696 Notebook3 Spotify Track Data Feature Engineering with Playlist Generation Test Code
#
# ## Project Title:
# Create and Build A Data Engineering Pipeline to Collect, Process, and Store Spotify Data. This is intended to be a fun project to look at who the most popular artists are, what their most popular tracks are , and look at some characteristics of the songs.
#
# ## NoteBook Description:
# This notebook creates new features on the Spotify track data. Once features are created and applied,the data will be checked for NANs. After cleaning, A Euclidian Distance will be calculated from one on the engineered features called "custom_score" to determine song similarity.This song list will then be sent to my personal Spotify account for listening.
#
# ### Mary J Hollon
# ### Due 8-22-2024

# %%
import pandas as pd
import numpy as np


# Let's Load the data to examine its structure and contents

df = pd.read_csv('updated_tracks_2015.csv')

# Display basic information and the first few rows of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                400 non-null    object
#  1   name              400 non-null    object
#  2   artist_id         400 non-null    object
#  3   year              400 non-null    int64
#  4   popularity        400 non-null    int64
#  5   release_date      400 non-null    object
#  6   energy            398 non-null    float64
#  7   danceability      398 non-null    float64
#  8   instrumentalness  398 non-null    float64
#  9   loudness          398 non-null    float64
#  10  tempo             398 non-null    float64
#  11  valence           398 non-null    float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 37.6+ KB

# %% [markdown]
# This dataset contains 400 entries with the following columns:
#
# - id: Unique identifier for each track.
# - name: Name of the track.
# - artist_id: Identifier for the artist.
# - year: - year song was released
# - popularity: - this is the popularity score of the artist. The higher the score, the more popular the artist.
# - release_date: - the song's actual release date
# - energy: A float representing the intensity and activity of the track or how "loud" and "noisy" a track is. Values close to 0 are low energy and values close to 1 are high energy.
# - danceability: A float indicating how suitable a track is for dancing based on a combination of musical elements. A value of 0 is the least danceable, a value of 1 is the most danceable.
# - instrumentalness: A float predicting whether a track has no vocals.Values close to 0 have more vocal content, values close to 1 do not have vocal content
# - loudness: A float representing the overall loudness of the track in decibels.The closer to 0 the louder the track and farther away from zero or large in absolute value, the softer or lower the track.
# - tempo: A float indicating the tempo of the track in beats per minute. It indicates the "speed" or "pace" of the music
# - valence: A float describing the musical positiveness conveyed by a track. Values closer to 0 are more sad or angry, while values closer to 1 are more happy or cheerful.
#
#
# Source: https://developer.spotify.com/documentation/web-api/reference/get-several-audio-features

# %%
df.head(10)
# Out:
#                        id                        name               artist_id  \
# 0  3fqwjXwUGN6vbzIwvyFMhx           Tennessee Whiskey  4YLtscXsxbVgi031ovDDdh
# 1  3pXF1nA74528Edde4of9CC                       Don't  2EMAnMvWE2eb56ToJVfCWs
# 2  0QZ5yyl6B6utIWkxeBDxQN            The Night We Met  6ltzsmQQbmdoHHbLZ4ZN25
# 3  6K4t31amVTZDgR3sKmwUJJ  The Less I Know The Better  5INjqkS1o8h1imAzPqGZBb
# 4  43PuMrRfbyyuz4QpZ3oAwN                    Exchange  2EMAnMvWE2eb56ToJVfCWs
# 5  6FBzhcfgGacfXF3AmtfEaX                    C U Girl  57vWImR43h4CaDao012Ofp
# 6  5E30LdtzQTGqRvNd7l6kG5                Daddy Issues  77SW9BnxLY8rJ0RciFqkHh
# 7  7fBv7CLKzipRk6EC6TWHOB                   The Hills  1Xyo4u8uXC1ZmMpatF05PJ
# 8  7H0ya83CMmgFcOhw0UB6ow                  Space Song  56ZTgzPBDge0OvCGgMO3OY
# 9  3iVcZ5G6tvkXZkZKlMpIUs                     Alright  2YZyLoL8N0Wb9xBt1NhZWg
#
#    year  popularity release_date  energy  danceability  instrumentalness  \
# 0  2015          83   2015-05-04   0.370         0.392           0.00960
# 1  2015          83   2015-10-02   0.356         0.765           0.00000
# 2  2015          78   2015-04-07   0.366         0.545           0.26700
# 3  2015          85   2015-07-17   0.740         0.640           0.00678
# 4  2015          81   2015-10-02   0.433         0.525           0.00000
# 5  2015          81   2015-02-15   0.473         0.414           0.05230
# 6  2015          85   2015-10-30   0.521         0.588           0.14900
# 7  2015          85   2015-08-28   0.564         0.585           0.00000
# 8  2015          77   2015-08-28   0.792         0.508           0.12400
# 9  2015          80   2015-03-16   0.766         0.796           0.00000
#
#    loudness    tempo  valence
# 0   -10.888   48.718    0.512
# 1    -5.556   96.991    0.189
# 2    -9.510   86.997    0.100
# 3    -4.083  116.879    0.785
# 4   -10.598  160.108    0.276
# 5    -8.911  100.000    0.409
# 6    -9.461   85.012    0.337
# 7    -7.063  113.003    0.137
# 8    -7.311  147.067    0.601
# 9    -5.974  110.034    0.558

# %% [markdown]
# Let's engineer some features to add to this data set.
#
# - Feature 1 - Categorize energy
# - Feature 2 - Categorize tempo
# - Feature 3 - Categorize danceability
# - Feature 4 - Categorize valance
# - Feature 5 - Create Interaction Term: Danceability and Valence
# - Feature 6 - Scale loudness with Min_Max Scaler
# - Feature 7 - Categorize scaled loudness
# - Feature 8 - Calculate a custon score for each track which can be used to determine similar tracks
#
# The danceability_valence_interaction is the product of danceability and valence for each track.This term provides a combined measure of how danceable and positive a track is. A higher interaction value indicates a track that is both highly danceable and conveys a positive mood. Conversely, a lower value might indicate a track that is either not very danceable, conveys a negative mood, or both.

# %%
from sklearn.preprocessing import MinMaxScaler

def apply_feature_engineering(df):
    # Feature 1: Energy Categories
    df['energy_category'] = pd.cut(df['energy'], bins=3, labels=['Low', 'Medium', 'High'])

    # Feature 2: Tempo Ranges
    def categorize_tempo(tempo):
        if tempo < 100:
            return 'Slow'
        elif tempo < 140:
            return 'Medium'
        else:
            return 'Fast'

    df['tempo_category'] = df['tempo'].apply(categorize_tempo)

    # Feature 3: Danceability Categories
    def categorize_danceability(danceability):
        if danceability is None:
            return 'Unknown'
        if danceability < 0.4:
            return 'Low'
        elif danceability < 0.7:
            return 'Medium'
        else:
            return 'High'

    df['danceability_category'] = df['danceability'].apply(categorize_danceability)
    
    # Feature 4: Classify Valence (or Mood) Categories
    def categorize_valence(valence):
        if valence < 0.3:
            return 'Sad'
        elif valence < 0.6:
            return 'Neutral'
        else:
            return 'Happy'

    df['valence_category'] = df['valence'].apply(categorize_valence)

    # Feature 5: Interaction Term: Danceability and Valence
    df['danceability_valence_interaction'] = df['danceability'] * df['valence']

    # Feature 6: Loudness Scaled With MinMax Scaler
    min_max_scaler = MinMaxScaler()
    df['loudness_scaled'] = min_max_scaler.fit_transform(df[['loudness']])

    # Feature 7: Define categories based on the min-max scaled loudness with four categories
    def categorize_loudness_scaled(loudness_scaled):
        if loudness_scaled <= 0.25:
            return 'Very Low'
        elif loudness_scaled <= 0.5:
            return 'Low'
        elif loudness_scaled <= 0.75:
            return 'High'
        else:
            return 'Very High'

    df['loudness_category'] = df['loudness_scaled'].apply(categorize_loudness_scaled)

    # Feature 8: Instrumentalness Categories
    def categorize_instrumentalness(instrumentalness):
        if instrumentalness == 0:
            return 'None'
        elif instrumentalness < 0.3:
            return 'Low'
        elif instrumentalness < 0.7:
            return 'Medium'
        else:
            return 'High'

    df['instrumentalness_category'] = df['instrumentalness'].apply(categorize_instrumentalness)

    return df

def calculate_custom_score(df, danceability_weight=0.30, energy_weight=0.25, valence_weight=0.25, loudness_weight=0.20):
    """
    Calculate a custom score for each track in the dataframe based on specified feature weights.

    Parameters:
    df (pd.DataFrame): The dataframe containing track features.
    danceability_weight (float): Weight for danceability feature.
    energy_weight (float): Weight for energy feature.
    valence_weight (float): Weight for valence feature.
    loudness_weight (float): Weight for loudness feature.

    Returns:
    pd.DataFrame: Dataframe with a new column 'custom_score'.
    """
    # Normalize selected features if not already normalized
    #It turns out I didn't need to scale danceability, energy, and valence because the values were already between 0 - 1.
    min_max_scaler = MinMaxScaler()

    
    # Calculate the custom score
    df['custom_score'] = (df['danceability'] * danceability_weight +
                          df['energy'] * energy_weight +
                          df['valence'] * valence_weight +
                          df['loudness_scaled'] * loudness_weight)

    return df

# %%
# Let's apply the feature engineering functions above to the track data
# Process files from 2015 to 2024 

for year in range(2015, 2025):
    file_path = f'updated_tracks_{year}.csv'
    
    try:
        df = pd.read_csv(file_path)
        df = apply_feature_engineering(df)
        df = calculate_custom_score(df)
        
        # Save or display the processed data
        df.to_csv(f'processed_tracks_{year}.csv', index=False)
        
        # Optionally display the first few rows
        print(f"Processed tracks_{year}.csv")
        print(df.head())
    except FileNotFoundError:
        print(f"File tracks_{year}.csv not found.")
# Out:
# Processed tracks_2015.csv
#                        id                        name               artist_id  \
# 0  3fqwjXwUGN6vbzIwvyFMhx           Tennessee Whiskey  4YLtscXsxbVgi031ovDDdh
# 1  3pXF1nA74528Edde4of9CC                       Don't  2EMAnMvWE2eb56ToJVfCWs
# 2  0QZ5yyl6B6utIWkxeBDxQN            The Night We Met  6ltzsmQQbmdoHHbLZ4ZN25
# 3  6K4t31amVTZDgR3sKmwUJJ  The Less I Know The Better  5INjqkS1o8h1imAzPqGZBb
# 4  43PuMrRfbyyuz4QpZ3oAwN                    Exchange  2EMAnMvWE2eb56ToJVfCWs
#
#    year  popularity release_date  energy  danceability  instrumentalness  \
# 0  2015          83   2015-05-04   0.370         0.392           0.00960
# 1  2015          83   2015-10-02   0.356         0.765           0.00000
# 2  2015          78   2015-04-07   0.366         0.545           0.26700
# 3  2015          85   2015-07-17   0.740         0.640           0.00678
# 4  2015          81   2015-10-02   0.433         0.525           0.00000
#
#    loudness  ...  valence  energy_category tempo_category  \
# 0   -10.888  ...    0.512           Medium           Slow
# 1    -5.556  ...    0.189           Medium           Slow
# 2    -9.510  ...    0.100           Medium           Slow
# 3    -4.083  ...    0.785             High         Medium
# 4   -10.598  ...    0.276           Medium           Fast
#
#   danceability_category valence_category danceability_valence_interaction  \
# 0                   Low          Neutral                         0.200704
# 1                  High              Sad                         0.144585
# 2                Medium              Sad                         0.054500
# 3                Medium            Happy                         0.502400
# 4                Medium              Sad                         0.144900
#
#    loudness_scaled  loudness_category instrumentalness_category custom_score
# 0         0.688470               High                       Low     0.475794
# 1         0.870686          Very High                      None     0.539887
# 2         0.735561               High                       Low     0.427112
# 3         0.921024          Very High                       Low     0.757455
# 4         0.698380               High                      None     0.474426
#
# [5 rows x 21 columns]
# Processed tracks_2016.csv
#                        id                           name  \
# 0  3xKsf9qdS1CyvXSMEid6g8                   Pink + White
# 1  3IznIgmXtrUaoPWpQTy5jB                    Not Allowed
# 2  6QeYSvYqYUsfBzsApbjDHO      Cigarettes out the Window
# 3  2ZWlPOoWh0626oTaHrnl2a                            Ivy
# 4  4KW1lqgSr8TKrvBII0Brf8  Father Stretch My Hands Pt. 1
#
#                 artist_id  year  popularity release_date  energy  \
# 0  2h93pZq0e7k5yf4dywlkpM  2016          88   2016-08-20   0.545
# 1  0Y6dVaC9DZtPNH4591M42W  2016          85   2016-02-25   0.905
# 2  0Y6dVaC9DZtPNH4591M42W  2016          84   2016-02-25   0.659
# 3  2h93pZq0e7k5yf4dywlkpM  2016          83   2016-08-20   0.386
# 4  5K4W6rqBFWDnAN6FQUkS6x  2016          84   2016-06-10   0.573
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0         0.545          0.000055    -7.362  ...    0.549           Medium
# 1         0.670          0.000227    -6.855  ...    0.563             High
# 2         0.625          0.000000    -5.669  ...    0.594           Medium
# 3         0.575          0.000289    -9.584  ...    0.466           Medium
# 4         0.724          0.000000    -4.113  ...    0.438           Medium
#
#   tempo_category danceability_category valence_category  \
# 0           Fast                Medium          Neutral
# 1         Medium                Medium          Neutral
# 2         Medium                Medium          Neutral
# 3         Medium                Medium          Neutral
# 4         Medium                  High          Neutral
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                         0.299205         0.827600          Very High
# 1                         0.377210         0.841826          Very High
# 2                         0.371250         0.875105          Very High
# 3                         0.267950         0.765251          Very High
# 4                         0.317112         0.918766          Very High
#
#   instrumentalness_category custom_score
# 0                       Low     0.602520
# 1                       Low     0.736365
# 2                      None     0.675771
# 3                       Low     0.538550
# 4                      None     0.653703
#
# [5 rows x 21 columns]
# Processed tracks_2017.csv
#                        id                                name  \
# 0  7KA4W4McWYRpgf0fWsJZWB    See You Again (feat. Kali Uchis)
# 1  1mMLMZYXkMueg65jRRWG1l              When It Rains It Pours
# 2  6me7F0aaZjwDo6RJ5MrfBD                           Evergreen
# 3  7sO5G9EABYOXQKNPNiE9NR  Ric Flair Drip (with Metro Boomin)
# 4  3EaJDYHA0KnX88JvDhL9oa                            Dark Red
#
#                 artist_id  year  popularity release_date  energy  \
# 0  4V8LLVI7PbaPR0K2TGSxFF  2017          89   2017-07-21   0.559
# 1  718COspgdWOnwOFpJHRZHS  2017          84   2017-06-02   0.801
# 2  4qU7IJSReZnsLy5907Mtau  2017          89   2017-05-17   0.216
# 3  4DdkRBBYG6Yk9Ka8tdJ9BW  2017          85   2017-10-30   0.428
# 4  57vWImR43h4CaDao012Ofp  2017          86   2017-02-20   0.784
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0         0.558          0.000007    -9.222  ...    0.620           Medium
# 1         0.551          0.000006    -5.069  ...    0.625             High
# 2         0.555          0.004160   -11.661  ...    0.504              Low
# 3         0.880          0.000051    -8.280  ...    0.333           Medium
# 4         0.603          0.000008    -4.023  ...    0.769             High
#
#   tempo_category danceability_category valence_category  \
# 0           Slow                Medium            Happy
# 1         Medium                Medium            Happy
# 2           Slow                Medium          Neutral
# 3         Medium                  High          Neutral
# 4           Fast                Medium            Happy
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                         0.345960         0.614083               High
# 1                         0.344375         0.823862          Very High
# 2                         0.279720         0.490882                Low
# 3                         0.293040         0.661666               High
# 4                         0.463707         0.876698          Very High
#
#   instrumentalness_category custom_score
# 0                       Low     0.584967
# 1                       Low     0.686572
# 2                       Low     0.444676
# 3                       Low     0.586583
# 4                       Low     0.744490
#
# [5 rows x 21 columns]
# Processed tracks_2018.csv
#                        id                      name               artist_id  \
# 0  698eQRku24PIYPQPHItKlA    She Got the Best of Me  718COspgdWOnwOFpJHRZHS
# 1  2rxQMGVafnNaRaXlRMWPde           Beautiful Crazy  718COspgdWOnwOFpJHRZHS
# 2  3GCdLUSnKSMJhs4Tj6CV3s  All The Stars (with SZA)  2YZyLoL8N0Wb9xBt1NhZWg
# 3  7yNf9YjeO5JXUE3JEBgnYc                  Babydoll  6USv9qhCn6zfxlBQIYJ9qs
# 4  57TEkZN3f84tFJFHFrD4pO           Whiskey Glasses  4oUHIQIBe0LHzYfvXNW4QM
#
#    year  popularity release_date  energy  danceability  instrumentalness  \
# 0  2018          83   2018-06-01   0.907         0.533          0.000000
# 1  2018          82   2018-06-01   0.402         0.551          0.000000
# 2  2018          86   2018-02-09   0.633         0.695          0.000195
# 3  2018          84   2018-10-16   0.604         0.762          0.000000
# 4  2018          80   2018-04-27   0.680         0.616          0.000001
#
#    loudness  ...  valence  energy_category tempo_category  \
# 0    -3.793  ...    0.700             High           Fast
# 1    -7.431  ...    0.382           Medium         Medium
# 2    -4.946  ...    0.557           Medium           Slow
# 3    -5.296  ...    0.847           Medium           Fast
# 4    -4.581  ...    0.687             High           Fast
#
#   danceability_category valence_category danceability_valence_interaction  \
# 0                Medium            Happy                         0.373100
# 1                Medium          Neutral                         0.210482
# 2                Medium          Neutral                         0.387115
# 3                  High            Happy                         0.645414
# 4                Medium            Happy                         0.423192
#
#    loudness_scaled  loudness_category instrumentalness_category custom_score
# 0         0.934278          Very High                      None     0.748506
# 1         0.785308          Very High                      None     0.518362
# 2         0.887064          Very High                       Low     0.683413
# 3         0.872732          Very High                      None     0.765896
# 4         0.902011          Very High                       Low     0.706952
#
# [5 rows x 21 columns]
# Processed tracks_2019.csv
#                        id                       name               artist_id  \
# 0  2Dct3GykKZ58hpWRFfe2Qd              Heading South  40ZNYROS4zLfyyBSs2PGe2
# 1  1BxfuPKGuaTgP7aM0Bbdwr               Cruel Summer  06HL4z0CvFAxyc27GXpf02
# 2  7aEtlGHoiPAfRB084NiDmx  Beer Never Broke My Heart  718COspgdWOnwOFpJHRZHS
# 3  0fCwTrRNfoNk962ati8n2K                 All Your'n  13ZEDW6vyBF12HYcZRr4EV
# 4  7cA3PnUQDlUyBBwpRozQeo               One Man Band  6y8XlgIV8BLlIg1tT1R10i
#
#    year  popularity release_date  energy  danceability  instrumentalness  \
# 0  2019          86   2019-09-30   0.246         0.680          0.000000
# 1  2019          92   2019-08-23   0.702         0.552          0.000021
# 2  2019          81   2019-11-08   0.863         0.538          0.000000
# 3  2019          80   2019-08-02   0.550         0.585          0.000040
# 4  2019          80   2019-10-25   0.358         0.706          0.000000
#
#    loudness  ...  valence  energy_category tempo_category  \
# 0   -14.112  ...    0.388              Low         Medium
# 1    -5.707  ...    0.564             High           Fast
# 2    -4.483  ...    0.637             High           Slow
# 3    -7.342  ...    0.839           Medium           Slow
# 4    -8.331  ...    0.478           Medium           Slow
#
#   danceability_category valence_category danceability_valence_interaction  \
# 0                Medium          Neutral                         0.263840
# 1                Medium          Neutral                         0.311328
# 2                Medium            Happy                         0.342706
# 3                Medium            Happy                         0.490815
# 4                  High          Neutral                         0.337468
#
#    loudness_scaled  loudness_category instrumentalness_category custom_score
# 0         0.638158               High                      None     0.490132
# 1         0.886466          Very High                       Low     0.659393
# 2         0.922627          Very High                      None     0.720925
# 3         0.838164          Very High                       Low     0.690383
# 4         0.808946          Very High                      None     0.582589
#
# [5 rows x 21 columns]
# Processed tracks_2020.csv
#                        id                                     name  \
# 0  0zirWZTcXBBwGsevrsIpvT  Clean Baby Sleep White Noise (Loopable)
# 1  3FU6urUVsgXa6RBuV2PdRk          Heartless (feat. Morgan Wallen)
# 2  2UikqkwBv7aIvlixeVXHWt                You Should Probably Leave
# 3  3hxIUxnT27p5WcmjGUXNwx                  Shut up My Moms Calling
# 4  3jHdKaLCkuNEkWcLVmQPCX                            BEST INTEREST
#
#                 artist_id  year  popularity release_date  energy  \
# 0  6Cqtx9fpxzggIMuKn0RGCp  2020          93   2020-04-29     NaN
# 1  5fMUXHkw8R8eOP2RNVYEZX  2020          82   2020-05-29   0.556
# 2  4YLtscXsxbVgi031ovDDdh  2020          83   2020-11-13   0.477
# 3  35WVTyRnKAoaGExqgktVyb  2020          87   2020-02-10   0.409
# 4  4V8LLVI7PbaPR0K2TGSxFF  2020          82   2020-01-25   0.575
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0           NaN               NaN       NaN  ...      NaN              NaN
# 1         0.765          0.000000    -6.417  ...    0.274           Medium
# 2         0.602          0.000031    -8.425  ...    0.552           Medium
# 3         0.485          0.000000   -10.711  ...    0.376           Medium
# 4         0.596          0.000153    -8.325  ...    0.340           Medium
#
#   tempo_category danceability_category valence_category  \
# 0           Fast                  High            Happy
# 1         Medium                  High              Sad
# 2           Fast                Medium          Neutral
# 3         Medium                Medium          Neutral
# 4           Slow                Medium          Neutral
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                              NaN              NaN          Very High
# 1                         0.209610         0.820886          Very High
# 2                         0.332304         0.752626          Very High
# 3                         0.182360         0.674916               High
# 4                         0.202640         0.756025          Very High
#
#   instrumentalness_category custom_score
# 0                      High          NaN
# 1                      None     0.601177
# 2                       Low     0.588375
# 3                      None     0.476733
# 4                       Low     0.558755
#
# [5 rows x 21 columns]
# Processed tracks_2021.csv
#                        id                   name               artist_id  \
# 0  3cBsEDNhFI9E82vPj3kvi3          Wasted On You  4oUHIQIBe0LHzYfvXNW4QM
# 1  69AIpwGNLxr4qS1X5ynx60               Buy Dirt  77kULmXAQ6vWer7IIHdGzI
# 2  4S4QJfBGGrC8jRIjJHf1Ka                   Pain  78rUTD7y6Cy67W1RVzYs7t
# 3  3azJifCSqg9fRij2yKIbWz       The Color Violet  2jku7tDXc6XoB6MO2hFuqg
# 4  5OELUCYgOHKFAvCERnAvfS  More Than My Hometown  4oUHIQIBe0LHzYfvXNW4QM
#
#    year  popularity release_date  energy  danceability  instrumentalness  \
# 0  2021          82   2021-01-08   0.657         0.505           0.00107
# 1  2021          80   2021-05-21   0.559         0.586           0.00000
# 2  2021          83   2021-10-15   0.617         0.829           0.00306
# 3  2021          84   2021-12-10   0.534         0.645           0.00000
# 4  2021          79   2021-01-08   0.869         0.620           0.00000
#
#    loudness  ...  valence  energy_category tempo_category  \
# 0    -5.240  ...    0.252           Medium           Fast
# 1    -6.725  ...    0.437           Medium           Fast
# 2    -8.497  ...    0.810           Medium         Medium
# 3   -10.800  ...    0.463           Medium         Medium
# 4    -5.479  ...    0.597             High         Medium
#
#   danceability_category valence_category danceability_valence_interaction  \
# 0                Medium              Sad                         0.127260
# 1                Medium          Neutral                         0.256082
# 2                  High            Happy                         0.671490
# 3                Medium          Neutral                         0.298635
# 4                Medium          Neutral                         0.370140
#
#    loudness_scaled  loudness_category instrumentalness_category custom_score
# 0         0.897591          Very High                       Low     0.558268
# 1         0.858925          Very High                      None     0.596585
# 2         0.812785          Very High                       Low     0.768007
# 3         0.752819          Very High                      None     0.593314
# 4         0.891368          Very High                      None     0.730774
#
# [5 rows x 21 columns]
# Processed tracks_2022.csv
#                        id                     name               artist_id  \
# 0  0mflMxspEfB0VbI1kyLiAv             Stick Season  2RQXRUsr4IW1f3mKyKsy4B
# 1  3WMj8moIAXJhHsyLaqIIHI  Something in the Orange  40ZNYROS4zLfyyBSs2PGe2
# 2  1SjsVdSXpwm1kTdYEHoPIT                Sun to Me  40ZNYROS4zLfyyBSs2PGe2
# 3  3qhlB30KknSejmIvZZLjOD         End of Beginning  5p9HO3XC5P3BLxJs5Mtrhm
# 4  0OWhKvvsHptt6vnnNUSM9a       Oklahoma Smokeshow  40ZNYROS4zLfyyBSs2PGe2
#
#    year  popularity release_date  energy  danceability  instrumentalness  \
# 0  2022          90   2022-10-14   0.500         0.664          0.000000
# 1  2022          87   2022-04-22   0.192         0.369          0.000008
# 2  2022          85   2022-05-20   0.270         0.505          0.000000
# 3  2022          92   2022-09-16   0.454         0.689          0.002590
# 4  2022          83   2022-07-15   0.573         0.544          0.000000
#
#    loudness  ...  valence  energy_category tempo_category  \
# 0    -6.935  ...    0.801           Medium         Medium
# 1   -12.151  ...    0.148              Low           Fast
# 2    -9.165  ...    0.557              Low           Slow
# 3    -7.643  ...    0.912           Medium           Fast
# 4    -5.694  ...    0.233           Medium         Medium
#
#   danceability_category valence_category danceability_valence_interaction  \
# 0                Medium            Happy                         0.531864
# 1                   Low              Sad                         0.054612
# 2                Medium          Neutral                         0.281285
# 3                Medium            Happy                         0.628368
# 4                Medium              Sad                         0.126752
#
#    loudness_scaled  loudness_category instrumentalness_category custom_score
# 0         0.834061          Very High                      None     0.691262
# 1         0.699263               High                       Low     0.335553
# 2         0.776431          Very High                      None     0.513536
# 3         0.815764          Very High                       Low     0.711353
# 4         0.866133          Very High                      None     0.537927
#
# [5 rows x 21 columns]
# Processed tracks_2023.csv
#                        id                                           name  \
# 0  4xdBrk0nFZaP54vvZj0yx7                                     HOT TO GO!
# 1  4KULAymBBJcPRpk1yO4dOG  I Remember Everything (feat. Kacey Musgraves)
# 2  7FOgcfdz9Nx5V9lCNXdBYv                             Red Wine Supernova
# 3  1k2pQc5i348DCHwbn5KTdc                                 Pink Pony Club
# 4  7fveJ3pk1eSfxBdVkzdXZ0                        Cowgirls (feat. ERNEST)
#
#                 artist_id  year  popularity release_date  energy  \
# 0  7GlBOeep6PqTfFi59PTUUN  2023          91   2023-09-22   0.757
# 1  40ZNYROS4zLfyyBSs2PGe2  2023          89   2023-08-25   0.453
# 2  7GlBOeep6PqTfFi59PTUUN  2023          88   2023-09-22   0.820
# 3  7GlBOeep6PqTfFi59PTUUN  2023          88   2023-09-22   0.650
# 4  4oUHIQIBe0LHzYfvXNW4QM  2023          86   2023-03-03   0.779
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0         0.742          0.000000    -4.981  ...    0.957             High
# 1         0.429          0.000002    -7.746  ...    0.155           Medium
# 2         0.657          0.000000    -4.448  ...    0.709             High
# 3         0.610          0.000000    -6.199  ...    0.507           Medium
# 4         0.621          0.000009    -3.777  ...    0.399             High
#
#   tempo_category danceability_category valence_category  \
# 0         Medium                  High            Happy
# 1           Slow                Medium              Sad
# 2         Medium                Medium            Happy
# 3         Medium                Medium          Neutral
# 4           Fast                Medium          Neutral
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                         0.710094         0.905248          Very High
# 1                         0.066495         0.829111          Very High
# 2                         0.465813         0.919925          Very High
# 3                         0.309270         0.871709          Very High
# 4                         0.247779         0.938402          Very High
#
#   instrumentalness_category custom_score
# 0                      None     0.832150
# 1                       Low     0.446522
# 2                      None     0.763335
# 3                      None     0.646592
# 4                       Low     0.668480
#
# [5 rows x 21 columns]
# Processed tracks_2024.csv
#                        id                                   name  \
# 0  0WbMK4wrZ1wFSty9F7FCgu                       Good Luck, Babe!
# 1  6AI3ezQ4o3HUoP6Dhudph3                            Not Like Us
# 2  6dOtVTDdiauQNBQEDOtlAB                     BIRDS OF A FEATHER
# 3  7221xIgOnuakPdLqT0F3nP  I Had Some Help (Feat. Morgan Wallen)
# 4  5N3hjp1WNayUPZrA8kJmJP                   Please Please Please
#
#                 artist_id  year  popularity release_date  energy  \
# 0  7GlBOeep6PqTfFi59PTUUN  2024          96   2024-04-05   0.582
# 1  2YZyLoL8N0Wb9xBt1NhZWg  2024          96   2024-05-04   0.472
# 2  6qqNVTkY8uBg9cP3Jd7DAH  2024         100   2024-05-17   0.507
# 3  246dkjvS1zLTtiykXe5h60  2024          94   2024-05-10   0.855
# 4  74KM79TiuVKeVCqs8QtB0B  2024          97   2024-06-06   0.586
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0         0.700            0.0000    -5.960  ...    0.785           Medium
# 1         0.898            0.0000    -7.001  ...    0.214           Medium
# 2         0.747            0.0608   -10.171  ...    0.438           Medium
# 3         0.638            0.0000    -4.860  ...    0.731             High
# 4         0.669            0.0000    -6.073  ...    0.579           Medium
#
#   tempo_category danceability_category valence_category  \
# 0         Medium                  High            Happy
# 1         Medium                  High              Sad
# 2         Medium                  High          Neutral
# 3         Medium                Medium            Happy
# 4         Medium                Medium          Neutral
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                         0.549500         0.669214               High
# 1                         0.192172         0.591972               High
# 2                         0.327186         0.356756                Low
# 3                         0.466378         0.750835          Very High
# 4                         0.387351         0.660830               High
#
#   instrumentalness_category custom_score
# 0                      None     0.685593
# 1                      None     0.559294
# 2                       Low     0.531701
# 3                      None     0.738067
# 4                      None     0.624116
#
# [5 rows x 21 columns]

# %%
# Let's check one of the files
df = pd.read_csv('processed_tracks_2020.csv')

# %%
df.head()
# Out:
#                        id                                     name  \
# 0  0zirWZTcXBBwGsevrsIpvT  Clean Baby Sleep White Noise (Loopable)
# 1  3FU6urUVsgXa6RBuV2PdRk          Heartless (feat. Morgan Wallen)
# 2  2UikqkwBv7aIvlixeVXHWt                You Should Probably Leave
# 3  3hxIUxnT27p5WcmjGUXNwx                  Shut up My Moms Calling
# 4  3jHdKaLCkuNEkWcLVmQPCX                            BEST INTEREST
#
#                 artist_id  year  popularity release_date  energy  \
# 0  6Cqtx9fpxzggIMuKn0RGCp  2020          93   2020-04-29     NaN
# 1  5fMUXHkw8R8eOP2RNVYEZX  2020          82   2020-05-29   0.556
# 2  4YLtscXsxbVgi031ovDDdh  2020          83   2020-11-13   0.477
# 3  35WVTyRnKAoaGExqgktVyb  2020          87   2020-02-10   0.409
# 4  4V8LLVI7PbaPR0K2TGSxFF  2020          82   2020-01-25   0.575
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0           NaN               NaN       NaN  ...      NaN              NaN
# 1         0.765          0.000000    -6.417  ...    0.274           Medium
# 2         0.602          0.000031    -8.425  ...    0.552           Medium
# 3         0.485          0.000000   -10.711  ...    0.376           Medium
# 4         0.596          0.000153    -8.325  ...    0.340           Medium
#
#   tempo_category danceability_category valence_category  \
# 0           Fast                  High            Happy
# 1         Medium                  High              Sad
# 2           Fast                Medium          Neutral
# 3         Medium                Medium          Neutral
# 4           Slow                Medium          Neutral
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                              NaN              NaN          Very High
# 1                         0.209610         0.820886          Very High
# 2                         0.332304         0.752626          Very High
# 3                         0.182360         0.674916               High
# 4                         0.202640         0.756025          Very High
#
#   instrumentalness_category custom_score
# 0                      High          NaN
# 1                      None     0.601177
# 2                       Low     0.588375
# 3                      None     0.476733
# 4                       Low     0.558755
#
# [5 rows x 21 columns]

# %%
# Let's check for Nans in the processed_track{year} files from 2015 to 2024 

for year in range(2015, 2025):
    file_path = f'processed_tracks_{year}.csv'
    try:
        df = pd.read_csv(file_path)
        nan_summary_before = df.isna().sum()
        print(f"NaN summary before dropping rows for {file_path}:\n{nan_summary_before}\n")
        
        # Drop rows with NaN values
        df_clean = df.dropna()
        
        nan_summary_after = df_clean.isna().sum()
        print(f"NaN summary after dropping rows for {file_path}:\n{nan_summary_after}\n")
        
        # Save the cleaned dataframe back to the CSV file
        df_clean.to_csv(file_path, index=False)
        
    except FileNotFoundError:
        print(f"{file_path} not found.")
# Out:
# NaN summary before dropping rows for processed_tracks_2015.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              2
# danceability                        2
# instrumentalness                    2
# loudness                            2
# tempo                               2
# valence                             2
# energy_category                     2
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    2
# loudness_scaled                     2
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        2
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2015.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2016.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              1
# danceability                        1
# instrumentalness                    1
# loudness                            1
# tempo                               1
# valence                             1
# energy_category                     1
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    1
# loudness_scaled                     1
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        1
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2016.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2017.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              3
# danceability                        3
# instrumentalness                    3
# loudness                            3
# tempo                               3
# valence                             3
# energy_category                     3
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    3
# loudness_scaled                     3
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        3
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2017.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2018.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2018.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2019.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2019.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2020.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              1
# danceability                        1
# instrumentalness                    1
# loudness                            1
# tempo                               1
# valence                             1
# energy_category                     1
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    1
# loudness_scaled                     1
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        1
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2020.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2021.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              8
# danceability                        8
# instrumentalness                    8
# loudness                            8
# tempo                               8
# valence                             8
# energy_category                     8
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    8
# loudness_scaled                     8
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        8
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2021.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2022.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              6
# danceability                        6
# instrumentalness                    6
# loudness                            6
# tempo                               6
# valence                             6
# energy_category                     6
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    6
# loudness_scaled                     6
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        6
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2022.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2023.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2023.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary before dropping rows for processed_tracks_2024.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64
#
# NaN summary after dropping rows for processed_tracks_2024.csv:
# id                                  0
# name                                0
# artist_id                           0
# year                                0
# popularity                          0
# release_date                        0
# energy                              0
# danceability                        0
# instrumentalness                    0
# loudness                            0
# tempo                               0
# valence                             0
# energy_category                     0
# tempo_category                      0
# danceability_category               0
# valence_category                    0
# danceability_valence_interaction    0
# loudness_scaled                     0
# loudness_category                   0
# instrumentalness_category           0
# custom_score                        0
# dtype: int64

# %% [markdown]
# We have handled the missing values. Let's use Euclidian Distance and the song custom score to determine similar tracks ( just for fun )

# %%
df=pd.read_csv('processed_tracks_2017.csv')
df.head()
# Out:
#                        id                                name  \
# 0  7KA4W4McWYRpgf0fWsJZWB    See You Again (feat. Kali Uchis)
# 1  1mMLMZYXkMueg65jRRWG1l              When It Rains It Pours
# 2  6me7F0aaZjwDo6RJ5MrfBD                           Evergreen
# 3  7sO5G9EABYOXQKNPNiE9NR  Ric Flair Drip (with Metro Boomin)
# 4  3EaJDYHA0KnX88JvDhL9oa                            Dark Red
#
#                 artist_id  year  popularity release_date  energy  \
# 0  4V8LLVI7PbaPR0K2TGSxFF  2017          89   2017-07-21   0.559
# 1  718COspgdWOnwOFpJHRZHS  2017          84   2017-06-02   0.801
# 2  4qU7IJSReZnsLy5907Mtau  2017          89   2017-05-17   0.216
# 3  4DdkRBBYG6Yk9Ka8tdJ9BW  2017          85   2017-10-30   0.428
# 4  57vWImR43h4CaDao012Ofp  2017          86   2017-02-20   0.784
#
#    danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0         0.558          0.000007    -9.222  ...    0.620           Medium
# 1         0.551          0.000006    -5.069  ...    0.625             High
# 2         0.555          0.004160   -11.661  ...    0.504              Low
# 3         0.880          0.000051    -8.280  ...    0.333           Medium
# 4         0.603          0.000008    -4.023  ...    0.769             High
#
#   tempo_category danceability_category valence_category  \
# 0           Slow                Medium            Happy
# 1         Medium                Medium            Happy
# 2           Slow                Medium          Neutral
# 3         Medium                  High          Neutral
# 4           Fast                Medium            Happy
#
#   danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                         0.345960         0.614083               High
# 1                         0.344375         0.823862          Very High
# 2                         0.279720         0.490882                Low
# 3                         0.293040         0.661666               High
# 4                         0.463707         0.876698          Very High
#
#   instrumentalness_category custom_score
# 0                       Low     0.584967
# 1                       Low     0.686572
# 2                       Low     0.444676
# 3                       Low     0.586583
# 4                       Low     0.744490
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                397 non-null    object
#  1   name                              397 non-null    object
#  2   artist_id                         397 non-null    object
#  3   year                              397 non-null    int64
#  4   popularity                        397 non-null    int64
#  5   release_date                      397 non-null    object
#  6   energy                            397 non-null    float64
#  7   danceability                      397 non-null    float64
#  8   instrumentalness                  397 non-null    float64
#  9   loudness                          397 non-null    float64
#  10  tempo                             397 non-null    float64
#  11  valence                           397 non-null    float64
#  12  energy_category                   397 non-null    object
#  13  tempo_category                    397 non-null    object
#  14  danceability_category             397 non-null    object
#  15  valence_category                  397 non-null    object
#  16  danceability_valence_interaction  397 non-null    float64
#  17  loudness_scaled                   397 non-null    float64
#  18  loudness_category                 397 non-null    object
#  19  instrumentalness_category         397 non-null    object
#  20  custom_score                      397 non-null    float64
# dtypes: float64(9), int64(2), object(10)
# memory usage: 65.3+ KB

# %%
from scipy.spatial.distance import euclidean

# Function to find similar tracks based on custom score
def find_similar_tracks(df, track_name, top_n=5):
    
    # Check if the track name exists in the dataframe
    if track_name not in df['name'].values:
        raise ValueError(f"Track name '{track_name}' not found in the dataset.")
    
    # Get the custom score of the reference track
    reference_score = df.loc[df['name'] == track_name, 'custom_score'].values[0]
    
    # Calculate the Euclidean distance between the reference score and all other scores
    df['similarity'] = df['custom_score'].apply(lambda x: euclidean([x], [reference_score]))
    
    # Sort by similarity (ascending) and exclude the reference track itself
    similar_tracks = df[df['name'] != track_name].sort_values(by='similarity', ascending=True).head(top_n)
    
    # Return the most similar tracks
    return similar_tracks[['id','name', 'artist_id', 'custom_score', 'similarity']]

# %%
# let's call the function and try it out !
# It may be useful later !

df = pd.read_csv('processed_tracks_2020.csv')

# Example: Find similar tracks to a given track name
similar_tracks = find_similar_tracks(df, track_name="You Should Probably Leave", top_n=25)

similar_tracks
# Out:
#                          id                                    name  \
# 259  4HBZA5flZLE435QTztThqH       Stuck with U (with Justin Bieber)
# 15   7s5VQqrjBtrBgZL4pEa46S                          Romantic Lover
# 7    0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 242  40TPiJpvwGIyvPjJMDTKfy          Rags2Riches 2 (feat. Lil Baby)
# 233  4N7i6RfJXMWfkx9Zr6pzkJ                 E-ER (feat. Lil Yachty)
# 173  67q8yivDoOPXCYodi1zTix                        Glue Myself Shut
# 355  1DRLIUG8HFTBfJOFYaByZn                              FORMATIONS
# 324  4R5GN0mBvb6jkRj3Zvyhkl                   Will I See You Again?
# 103  01JMnRUs2YOK6DDpdQASGY                   Grace (feat. 42 Dugg)
# 111  2xB46Bj9HZ4cr058yN4Pla                                 Secrets
# 288  2SSyJ6hTS0JeHTg63wVDZ7                             Next To You
# 113  5MbtltJOrf5hTldbvaEqdV                    Bottle and Mary Jane
# 165  2QdSb68BzZGMgCbsrFmSLc                                  Higher
# 262  3DA4SE262k6rdEtlHteNyq                 Die From A Broken Heart
# 21   6IBcOGPsniK3Pso1wHIhew                       Forever After All
# 192  5dOxHHMOFAbG3VH23t0xNm                               Righteous
# 295  7ge7BHazYbVKi8qyZUX1Bm                     Emotionally Scarred
# 188  3xgT3xIlFGqZjYW9QlhJWp  Dancing With A Stranger (with Normani)
# 70   6bnF93Rx87YqUBLSgjiMU8                               Heartless
# 335  4CLkDJ4xLqkV4Vt2vPOny1                       Palabra de Hombre
# 158  2297mxrYLBAC4XkhXs39If                       Armed & Dangerous
# 142  0awZwmlC6pxH65KTZpadmX          Freakin' Out On the Interstate
# 44   1w327AHTCoChRIkJUprAnV                                  Mirage
# 389  7AWgHNS16hOhmiyPIRRcmC                      El Amor De Tu Vida
# 138  0OPcFAAo9LMO9xvu1L7JGD                             Perc Popper
#
#                   artist_id  custom_score  similarity
# 259  66CXWjxzNUsdJxJ2JdwvnR      0.588389    0.000013
# 15   3XxNRirzbjfLdDli06zMaB      0.588233    0.000142
# 7    1Xyo4u8uXC1ZmMpatF05PJ      0.587320    0.001055
# 242  45TgXXqMDdF8BkjA83OM7z      0.589796    0.001421
# 233  1m7LSAMIB1BErIHYSOn32W      0.586498    0.001878
# 173  2RQXRUsr4IW1f3mKyKsy4B      0.591069    0.002694
# 355  3Ka3k9K2WStR52UJVtbJZW      0.585671    0.002704
# 324  0oK5D6uPhGu4Jk2dbZfodU      0.585595    0.002780
# 103  5f7VJjfbwm532GiveGC0ZK      0.585424    0.002951
# 111  31W5EY0aAly4Qieq6OFu6I      0.591408    0.003033
# 288  2EMAnMvWE2eb56ToJVfCWs      0.591725    0.003350
# 113  19k8AgwwTSxeaxkOuCQEJs      0.583985    0.004390
# 165  687cZJR45JO7jhk1LHIbgq      0.593961    0.005586
# 262  34bhyY8jfKez7uKakMfy4y      0.582759    0.005617
# 21   718COspgdWOnwOFpJHRZHS      0.595085    0.006710
# 192  4MCBfE4596Uoi2O4DtmEMz      0.581617    0.006758
# 295  5f7VJjfbwm532GiveGC0ZK      0.581031    0.007344
# 188  2wY79sveU1sp5g7SokKOiI      0.595776    0.007400
# 70   1Xyo4u8uXC1ZmMpatF05PJ      0.580964    0.007411
# 335  0my6Pg4I28dVcZLSpAkqhv      0.596157    0.007782
# 158  6QtgPSJPSzcnn7dPZ4VINp      0.579902    0.008473
# 142  7vtSUU3zpHeYJfX6BPNrJd      0.597709    0.009334
# 44   2efrqekWSHlvhATD50AG3m      0.578823    0.009552
# 389  66ihevNkSYNzRAl44dx6jJ      0.578533    0.009842
# 138  4tYSBptyGeVyZsk8JC4JHZ      0.578397    0.009979

# %% [markdown]
# Let's develop some code to create a Public Playlist in my Spotify account
#
# ### NOTE: You MUST have Spotify Developer Credentials for this code to run !

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth, SpotifyClientCredentials
import pandas as pd
from spotify_credentials import SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET

# Authenticate with Spotify using OAuth
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIFY_CLIENT_ID,
                                               client_secret=SPOTIFY_CLIENT_SECRET,
                                               redirect_uri="your_redirect_uri",
                                               scope="playlist-modify-public"))

def write_playlist_to_spotify(similar_tracks_df, playlist_name="Similar Songs Playlist"):
    user_id = sp.current_user()["id"]

    # Create a new playlist
    playlist = sp.user_playlist_create(user=user_id, name=playlist_name, public=True, description="Playlist based on custom_score similarity")

    # Get track IDs
    track_ids = similar_tracks_df['id'].tolist()

    # Add tracks to the playlist
    sp.playlist_add_items(playlist_id=playlist['id'], items=track_ids)
    print(f"Playlist '{playlist_name}' created successfully with {len(track_ids)} tracks!")

# %%
# Example Usage
df = pd.read_csv('processed_tracks_2020.csv')

# Find similar tracks to a given track name
similar_tracks = find_similar_tracks(df, track_name="You Should Probably Leave", top_n=25)

# Write the similar_tracks DataFrame to Spotify
write_playlist_to_spotify(similar_tracks, playlist_name="Similar Tracks to 'You Should Probably Leave'")
# Out:
# Playlist 'Similar Tracks to 'You Should Probably Leave'' created successfully with 25 tracks!

# %% [markdown]
# Now, let's use the similar tracks based on euclidian distance to generate a playlist

# %%
# let's look at another example

df = pd.read_csv('processed_tracks_2024.csv')

df.head(25)
# Out:
#                         id                                               name  \
# 0   0WbMK4wrZ1wFSty9F7FCgu                                   Good Luck, Babe!
# 1   6AI3ezQ4o3HUoP6Dhudph3                                        Not Like Us
# 2   6dOtVTDdiauQNBQEDOtlAB                                 BIRDS OF A FEATHER
# 3   7221xIgOnuakPdLqT0F3nP              I Had Some Help (Feat. Morgan Wallen)
# 4   5N3hjp1WNayUPZrA8kJmJP                               Please Please Please
# 5   2qSkIjg1o9h3YT9RAgYN75                                           Espresso
# 6   5AJ9hqTS2wcFQCELCFRO7A                                MILLION DOLLAR BABY
# 7   2FQrifJ1N335Ljm3TjTVVf                                 A Bar Song (Tipsy)
# 8   4ZJ4vzLQekI0WntDbanNC7                                         Pink Skies
# 9   7Fzl7QaTu47WyP9R5S5mh5                                     Lies Lies Lies
# 10  5iJKGpnFfvbjZJeAtwXfCj                                                 28
# 11  629DixmZGHc7ILtEntuiWE                                              LUNCH
# 12  2tudvzsrR56uom6smgOcSf                                          Like That
# 13  2uqYupMHANxnwgeiXTZXzd                        Austin (Boots Stop Workin')
# 14  3WOhcATHxK2SLNeP5W3v1v                      Guess featuring Billie Eilish
# 15  7tI8dRuH2Yc6RuoTjxo4dU                                                Who
# 16  4w2GLmK2wnioVnb5CPQeex                                                360
# 17  3Vr3zh0r7ALn8VLqCiRR10                                         Stargazing
# 18  6GG4yyk3UATdBfTHVgI8PB  Ain't No Love In Oklahoma (From Twisters: The ...
# 19  5fZJQrFKWQLb7FpJXZ1g7K                                 A Bar Song (Tipsy)
# 20  19RybK6XDbAVpcdxSbZL1o                                              Apple
# 21  51eSHglvG1RJXtL3qI5trr                                       Slow It Down
# 22  3Pbp7cUCx4d3OAkZSCoNvn                                    Scared To Start
# 23  7BRD7x5pt8Lqa1eGYC4dzj                                            CHIHIRO
# 24  0AjmK0Eai4zGrLaJwPvrDp                                          Too Sweet
#
#                  artist_id  year  popularity release_date  energy  \
# 0   7GlBOeep6PqTfFi59PTUUN  2024          96   2024-04-05   0.582
# 1   2YZyLoL8N0Wb9xBt1NhZWg  2024          96   2024-05-04   0.472
# 2   6qqNVTkY8uBg9cP3Jd7DAH  2024         100   2024-05-17   0.507
# 3   246dkjvS1zLTtiykXe5h60  2024          94   2024-05-10   0.855
# 4   74KM79TiuVKeVCqs8QtB0B  2024          97   2024-06-06   0.586
# 5   74KM79TiuVKeVCqs8QtB0B  2024          98   2024-04-12   0.760
# 6   1WaFQSHVGZQJTbf0BdxdNo  2024          94   2024-04-26   0.697
# 7   3y2cIKLjiOlp1Np37WiUdH  2024          92   2024-04-12   0.709
# 8   40ZNYROS4zLfyyBSs2PGe2  2024          88   2024-05-24   0.488
# 9   4oUHIQIBe0LHzYfvXNW4QM  2024          87   2024-07-05   0.702
# 10  40ZNYROS4zLfyyBSs2PGe2  2024          87   2024-07-04   0.519
# 11  6qqNVTkY8uBg9cP3Jd7DAH  2024          93   2024-05-17   0.400
# 12  1RyvyyTE3xzB2ZywiAwp0i  2024          89   2024-03-22   0.676
# 13  7Ez6lTtSMjMf2YSYpukP1I  2024          91   2024-02-16   0.672
# 14  25uiPmTg16RbhZWAqwLBy5  2024          91   2024-08-01   0.667
# 15  1oSPZhvZMIrWW5I41kPkkY  2024          94   2024-07-19   0.756
# 16  25uiPmTg16RbhZWAqwLBy5  2024          89   2024-06-07   0.620
# 17  3bO19AOone0ubCsfDXDtYt  2024          93   2024-05-10   0.601
# 18  718COspgdWOnwOFpJHRZHS  2024          85   2024-05-16   0.658
# 19  3y2cIKLjiOlp1Np37WiUdH  2024          88   2024-05-31   0.706
# 20  25uiPmTg16RbhZWAqwLBy5  2024          89   2024-06-07   0.957
# 21  22wbnEMDvgVIAGdFeek6ET  2024          90   2024-04-05   0.583
# 22  4j96cMcT8GRi11qbvo1cLQ  2024          88   2024-01-12   0.551
# 23  6qqNVTkY8uBg9cP3Jd7DAH  2024          91   2024-05-17   0.425
# 24  2FXC3k01G6Gw61bmprjgqS  2024          83   2024-03-22   0.620
#
#     danceability  instrumentalness  loudness  ...  valence  energy_category  \
# 0          0.700          0.000000    -5.960  ...    0.785           Medium
# 1          0.898          0.000000    -7.001  ...    0.214           Medium
# 2          0.747          0.060800   -10.171  ...    0.438           Medium
# 3          0.638          0.000000    -4.860  ...    0.731             High
# 4          0.669          0.000000    -6.073  ...    0.579           Medium
# 5          0.701          0.000065    -5.478  ...    0.690             High
# 6          0.852          0.000370    -5.520  ...    0.919           Medium
# 7          0.722          0.000000    -4.950  ...    0.604             High
# 8          0.525          0.000051    -6.909  ...    0.253           Medium
# 9          0.486          0.000075    -5.758  ...    0.382             High
# 10         0.492          0.000085    -6.886  ...    0.435           Medium
# 11         0.893          0.082300    -7.981  ...    0.945              Low
# 12         0.814          0.000013    -4.670  ...    0.312           Medium
# 13         0.756          0.000003    -6.743  ...    0.739           Medium
# 14         0.776          0.300000    -6.622  ...    0.618           Medium
# 15         0.660          0.000000    -3.743  ...    0.838             High
# 16         0.857          0.244000    -8.130  ...    0.796           Medium
# 17         0.635          0.000000    -6.129  ...    0.332           Medium
# 18         0.487          0.007770    -9.973  ...    0.282           Medium
# 19         0.722          0.000000    -4.857  ...    0.599             High
# 20         0.804          0.017400    -5.452  ...    0.962             High
# 21         0.432          0.000000    -4.682  ...    0.544           Medium
# 22         0.527          0.000003   -11.258  ...    0.443           Medium
# 23         0.700          0.879000   -12.531  ...    0.521              Low
# 24         0.741          0.000809    -5.505  ...    0.934           Medium
#
#    tempo_category danceability_category valence_category  \
# 0          Medium                  High            Happy
# 1          Medium                  High              Sad
# 2          Medium                  High          Neutral
# 3          Medium                Medium            Happy
# 4          Medium                Medium          Neutral
# 5          Medium                  High            Happy
# 6          Medium                  High            Happy
# 7            Slow                  High            Happy
# 8            Slow                Medium              Sad
# 9            Slow                Medium          Neutral
# 10           Slow                Medium          Neutral
# 11         Medium                  High            Happy
# 12           Fast                  High          Neutral
# 13         Medium                  High            Happy
# 14         Medium                  High            Happy
# 15         Medium                Medium            Happy
# 16         Medium                  High            Happy
# 17         Medium                Medium          Neutral
# 18           Fast                Medium              Sad
# 19           Slow                  High          Neutral
# 20         Medium                  High            Happy
# 21           Fast                Medium          Neutral
# 22           Fast                Medium          Neutral
# 23         Medium                  High          Neutral
# 24         Medium                  High            Happy
#
#    danceability_valence_interaction  loudness_scaled  loudness_category  \
# 0                          0.549500         0.669214               High
# 1                          0.192172         0.591972               High
# 2                          0.327186         0.356756                Low
# 3                          0.466378         0.750835          Very High
# 4                          0.387351         0.660830               High
# 5                          0.483690         0.704979               High
# 6                          0.782988         0.701862               High
# 7                          0.436088         0.744157               High
# 8                          0.132825         0.598798               High
# 9                          0.185652         0.684203               High
# 10                         0.214020         0.600505               High
# 11                         0.843885         0.519255               High
# 12                         0.253968         0.764933          Very High
# 13                         0.558684         0.611115               High
# 14                         0.479568         0.620093               High
# 15                         0.553080         0.833717          Very High
# 16                         0.682172         0.508199               High
# 17                         0.210820         0.656674               High
# 18                         0.137334         0.371448                Low
# 19                         0.432478         0.751057          Very High
# 20                         0.773448         0.706908               High
# 21                         0.235008         0.764042          Very High
# 22                         0.233461         0.276100                Low
# 23                         0.364700         0.181643           Very Low
# 24                         0.692094         0.702975               High
#
#    instrumentalness_category custom_score
# 0                       None     0.685593
# 1                       None     0.559294
# 2                        Low     0.531701
# 3                       None     0.738067
# 4                       None     0.624116
# 5                        Low     0.713796
# 6                        Low     0.799972
# 7                       None     0.693681
# 8                        Low     0.462510
# 9                        Low     0.553641
# 10                       Low     0.506201
# 11                       Low     0.708001
# 12                       Low     0.644187
# 13                       Low     0.701773
# 14                    Medium     0.678069
# 15                      None     0.763243
# 16                       Low     0.712740
# 17                      None     0.555085
# 18                       Low     0.455390
# 19                      None     0.693061
# 20                       Low     0.862332
# 21                      None     0.564158
# 22                       Low     0.461820
# 23                      High     0.482829
# 24                       Low     0.751395
#
# [25 rows x 21 columns]

# %% [markdown]
# ### I will select the song "Please Please Please" by Sabrina Carpenter and generate similar tracks based on my similarity score

# %%
# let's call the function generate a list of similar songs in a dataframe before writing it to Spotify

df = pd.read_csv('processed_tracks_2024.csv')

# Example: Find similar tracks to a given track name
similar_tracks = find_similar_tracks(df, track_name="Please Please Please", top_n=25)

similar_tracks
# Out:
#                          id                                           name  \
# 152  4S8PxReB1UiDR2F5x1lyIR                               meet the grahams
# 351  3dzRwqd1L3HqxmViUJt20A                                   Sweet Dreams
# 188  2PgjJ90q1zETqCX68dxgyd                                   Sweet Dreams
# 36   6XjDF6nds4DE2BBbagZol6                                      Gata Only
# 177  0SdBkFh6u5IHIXqlBu0NyI                                      Yeah Glo!
# 94   5A8xI7PN4WDe9e61xEdt94                                      Yeah Glo!
# 325  150w1WjVxUWycZqTflcDAe       Goes Without Saying (Feat. Brad Paisley)
# 99   7Mg5CBO37Rifk2RyDJ8fzd                                      Boogieman
# 362  6XaJfhwof7qIgbbXO5tIQI           Igual Que Un Ángel (with Peso Pluma)
# 308  6slyBSVe8V4sZ6smTNukQJ                        What Don't Belong To Me
# 337  5GTBdEjZe7zEDp1N0eCZE4                                      HOLLYWOOD
# 341  5CYblb1W46TNSWMR7BBwS2     Death Wish Love (From Twisters: The Album)
# 182  4cfJwDxcinpg5gYUZ4qysj                                        Relapse
# 53   0y5Ex8oQ8zCH5TQxHUy1Eo  you look like you love me (feat. Riley Green)
# 221  6xZYGIixR3zhhOHwu7UEMY                                         mewtwo
# 298  3yjJCbT29Wc8ccWy9yag7l                        What Don't Belong To Me
# 121  36wAwEkSDpNQ4oQeRLYC3L                                     Am I Okay?
# 237  1DhtAZ3PjM7NLe2vLIRxLx                 Nosedive (Feat. Lainey Wilson)
# 104  55u5QIlEuzCipJBtZPdJio                                    Renaissance
# 275  4hHRQydZDHho0DphGUDG4u                  Wrong Ones (Feat. Tim McGraw)
# 43   4Na2HfNSr58chvfX69fy36                                     one of wun
# 67   1b8Uy52q8fZUBTlRkoXoT5               Housekeeping Knows (feat. Latto)
# 244  53MOb9isu1bJlCkDTObrCB                  Wrong Ones (Feat. Tim McGraw)
# 134  0gZGUAO42F1HmzZWHNPGAu                                           Risk
# 259  025Br9WLnUrOTamD9EUOv2       Goes Without Saying (Feat. Brad Paisley)
#
#                   artist_id  custom_score  similarity
# 152  2YZyLoL8N0Wb9xBt1NhZWg      0.624210    0.000094
# 351  1Tie3AZgLQZqYEp8Fv4zOZ      0.625238    0.001122
# 188  1Tie3AZgLQZqYEp8Fv4zOZ      0.625238    0.001122
# 36   7CvTknweLr9feJtRGrpDBy      0.625865    0.001749
# 177  2qoQgPAilErOKCwE2Y8wOG      0.621360    0.002756
# 94   2qoQgPAilErOKCwE2Y8wOG      0.621360    0.002756
# 325  246dkjvS1zLTtiykXe5h60      0.620203    0.003913
# 99   7iKgSlIINjat3bsCYiNMYX      0.628159    0.004044
# 362  1U1el3k54VvEUzo3ybLPlM      0.620044    0.004072
# 308  246dkjvS1zLTtiykXe5h60      0.619597    0.004519
# 337  12GqGscKJx3aE4t07u7eVZ      0.628635    0.004519
# 341  22wbnEMDvgVIAGdFeek6ET      0.629011    0.004895
# 182  7kplJl06UmldxLKseURAYi      0.617966    0.006150
# 53   6BRxQ8cD3eqnrVj6WKDok8      0.616860    0.007255
# 221  3gBZUcNeVumkeeJ19CY2sX      0.631759    0.007643
# 298  246dkjvS1zLTtiykXe5h60      0.631893    0.007777
# 121  5Ppie0uPnbnvGBYRwYmlt0      0.632816    0.008700
# 237  246dkjvS1zLTtiykXe5h60      0.633271    0.009155
# 104  7dGJo4pcD2V6oG8kP0tJRR      0.614566    0.009550
# 275  246dkjvS1zLTtiykXe5h60      0.634444    0.010328
# 43   2hlmm7s2ICUX0LVIhVFlZQ      0.613689    0.010427
# 67   3TVXtAsR1Inumwj472S9r4      0.634914    0.010798
# 244  246dkjvS1zLTtiykXe5h60      0.612225    0.011891
# 134  4tuJ0bMpJh08umKkEXKUI5      0.611962    0.012153
# 259  246dkjvS1zLTtiykXe5h60      0.611734    0.012382

# %%
# Example Usage
df = pd.read_csv('processed_tracks_2024.csv')

# Find similar tracks to a given track name
similar_tracks = find_similar_tracks(df, track_name="Please Please Please", top_n=25)

# Write the similar_tracks DataFrame to Spotify
write_playlist_to_spotify(similar_tracks, playlist_name="Similar Tracks to 'Please Please Please'")
# Out:
# Playlist 'Similar Tracks to 'Please Please Please'' created successfully with 25 tracks!

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth, SpotifyClientCredentials
import pandas as pd
from spotify_credentials import SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET

# Authenticate with Spotify using OAuth
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIFY_CLIENT_ID,
                                               client_secret=SPOTIFY_CLIENT_SECRET,
                                               redirect_uri="your_redirect_uri",
                                               scope="playlist-modify-public"))

def write_playlist_to_spotify(similar_tracks_df, playlist_name="Similar Songs Playlist"):
    user_id = sp.current_user()["id"]

    # Create a new playlist
    playlist = sp.user_playlist_create(user=user_id, name=playlist_name, public=True, description="Playlist based on custom_score similarity")

    # Get track IDs
    track_ids = similar_tracks_df['id'].tolist()

    # Add tracks to the playlist
    sp.playlist_add_items(playlist_id=playlist['id'], items=track_ids)
    
    # Print the success message with the playlist link
    playlist_url = playlist['external_urls']['spotify']
    print(f"Playlist '{playlist_name}' created successfully with {len(track_ids)} tracks!")
    print(f"Spotify Playlist Link: {playlist_url}")

# %% [markdown]
# ### Summary
#
# This file processes the updated_tracks_{year} files which were updated with track audio data. Feature Engineering is applied and NANs were removed. The new feature engineered and cleaned files are:
#
#  - processed_tracks_2015
#  - processed_tracks_2016
#  - processed_tracks_2017
#  - processed_tracks_2018
#  - processed_tracks_2019
#  - processed_tracks_2020
#  - processed_tracks_2021
#  - processed_tracks_2022
#  - processed_tracks_2023
#  - processed_tracks_2024
#
#
#
#  The test code to write a develop a playlist based on the feature custom_score has been developed and tested successfully

# %% [markdown]
# ## END of Notebook
